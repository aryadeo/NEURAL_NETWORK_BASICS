# %% [markdown]
# <a href="https://colab.research.google.com/github/aryadeo/NEURAL_NETWORK_BASICS/blob/master/MP_NEURON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #MP Neuron

# %% [markdown]
# ![sample_model](https://drive.google.com/uc?id=1WyG5pTQGYftDWCkbmdb_3kk_V84lin2v)

# %%
import numpy as np
import sklearn.datasets
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import pandas as pd

# %% [markdown]
# Loading the data and data wrangling

# %%
breast_cancer=sklearn.datasets.load_breast_cancer()

# %% [markdown]
# Objective: looking for a tissue in the dataset is malignant or belign.

# %%
X=breast_cancer.data
Y=breast_cancer.target

# %%
plt.plot(X.T,'o')
plt.show()

# %%
data=pd.DataFrame(breast_cancer.data,columns=breast_cancer.feature_names)

# %%
data.head()
# Out:
#    mean radius  mean texture  ...  worst symmetry  worst fractal dimension
# 0        17.99         10.38  ...          0.4601                  0.11890
# 1        20.57         17.77  ...          0.2750                  0.08902
# 2        19.69         21.25  ...          0.3613                  0.08758
# 3        11.42         20.38  ...          0.6638                  0.17300
# 4        20.29         14.34  ...          0.2364                  0.07678
#
# [5 rows x 30 columns]

# %%
data['class']=breast_cancer.target

# %%
data.head()
# Out:
#    mean radius  mean texture  ...  worst fractal dimension  class
# 0        17.99         10.38  ...                  0.11890      0
# 1        20.57         17.77  ...                  0.08902      0
# 2        19.69         21.25  ...                  0.08758      0
# 3        11.42         20.38  ...                  0.17300      0
# 4        20.29         14.34  ...                  0.07678      0
#
# [5 rows x 31 columns]
